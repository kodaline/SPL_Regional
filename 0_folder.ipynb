# %%
from IPython.core.display import display, HTML
import os

def list_files(startpath):
    output = "<ul>"
    stack = []
    
    for root, dirs, files in os.walk(startpath):
        # Remove hidden directories from the 'dirs' list in-place
        dirs[:] = [d for d in dirs if not d.startswith('.')]
        
        level = root.replace(startpath, '').count(os.sep)
        
        # Pop off elements from stack to get to the current level
        stack = stack[:level]
        
        indent = '    ' * level
        subindent = '    ' * (level + 1)
        
        # Skip hidden folders (those starting with .)
        if os.path.basename(root).startswith('.'):
            continue
            
        stack.append(f"{indent}<li><strong>{os.path.basename(root)}/</strong><ul>")
        
        # Sort the files alphabetically and limit to top 10
        files = sorted(files)[:10]
        
        for f in files:
            stack.append(f"{subindent}<li>{f}</li>")
        
        stack.append(f"{indent}</ul></li>")
        
    output += '\n'.join(stack)
    output += "</ul>"
    
    display(HTML(output))

# Replace '.' with the path to the directory you want to print.
list_files('.')
# Out:
# /tmp/ipykernel_33805/1216364021.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <ul>    <li><strong>Excel/</strong><ul>
#     <li><strong>Input/</strong><ul>
#         <li><strong>FantaSquadre/</strong><ul>
#             <li>FantaSquadre_Milano.xlsx</li>
#         </ul></li></ul>
